# %% [markdown]
# # **Visualisation for the Generated synthetic dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'NE_dataset.csv'
ne_data = pd.read_csv(file_path)

print(ne_data.head())

print(ne_data.info())
# Out:
#    NE_ID NE_Name   NE_Type  NE_Version Release_Version Board_Type  \
# 0   1001    NE_Z    Router         2.1           9.1.7     Type_H
# 1   1002    NE_E   Gateway         3.0           5.6.3     Type_B
# 2   1003    NE_V       Hub         5.0           1.0.5     Type_X
# 3   1004    NE_W       Hub         1.0           3.2.7     Type_U
# 4   1005    NE_V  Firewall         1.0           6.0.0     Type_S
#
#       IP_Address    Subnet_Mask        Gateway Configuration_Date  \
# 0  192.168.1.152  255.255.255.0    192.168.1.4         26-12-2024
# 1  192.168.1.185  255.255.255.0  192.168.1.191         23-12-2024
# 2   192.168.1.34  255.255.255.0  192.168.1.137         08-03-2024
# 3   192.168.1.83  255.255.255.0   192.168.1.91         11-04-2024
# 4   192.168.1.55  255.255.255.0  192.168.1.150         01-05-2024
#
#       Location         Vendor           Admin_Contact          Status  \
# 0   Birmingham          Ciena   contact31@company.com  Decommissioned
# ...

# %% [markdown]
# # **Bar plot for categorical columns**

# %%
categorical_cols = ne_data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    ne_data[col].value_counts().plot(kind='bar')
    plt.title(f'Bar plot of {col}')
    plt.ylabel('Frequency')
    plt.xlabel(col)
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # **Correlation heatmap for numerical columns**

# %%
numerical_cols = ne_data.select_dtypes(include=['number']).columns
if not numerical_cols.empty:
    plt.figure(figsize=(12, 8))
    sns.heatmap(ne_data[numerical_cols].corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap')
    plt.show()

# %% [markdown]
# # **Pairplot for quick multivariate analysis**

# %%
if len(numerical_cols) > 1:
    sns.pairplot(ne_data[numerical_cols])
    plt.show()
